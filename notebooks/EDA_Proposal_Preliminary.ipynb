# %% [markdown]
# # Senior Capstone Project

# %% [markdown]
# ### Data Science in Health: Infant Mortality

# %% [markdown]
# Preliminary EDA on health focused metrics in India

# %%
import os

dir = os.getcwd()
dir
# Out:
# '/home/rc/capstone/notebooks'

# %%
#%pip install pandas

# %%
import pandas as pd
import numpy as np

data = os.chdir("../data")
data
# !ls -l
# Out:
# total 2496
# drwxr-xr-x 3 rc rc    4096 Sep  3 01:44 Key_Indicator_State_and_District_wise_data
# -rw-r--r-- 1 rc rc   90112 Sep 13 04:59 Key_Indicators_Statewise.sqlite
# -rw-r--r-- 1 rc rc  976289 Sep 20  2019 Key_indicator_districtwise.csv
# -rw-r--r-- 1 rc rc   72192 Sep 20  2019 Key_indicator_statewise.csv
# -rwxrwxrwx 1 rc rc 1407790 Sep  3 01:38 healthanalytics.zip
# -rw-r--r-- 1 rc rc       0 Sep 13 05:00 statewise.sqlite

# %%
#!python3 --version
# Out:
# Python 3.12.3

# %%
key_indicator_statewise = pd.read_csv("Key_indicator_statewise.csv")
df = pd.DataFrame(key_indicator_statewise)
df.head(28)
# Out:
#        State_Name  AA_Sample_Units_Total  AA_Sample_Units_Rural  \
# 0           Assam                   1784                   1412
# 1           Bihar                   2356                   1981
# 2    Chhattisgarh                   1255                    926
# 3       Jharkhand                   2108                   1513
# 4  Madhya Pradesh                   2557                   1660
# 5          Odisha                   2364                   1798
# 6       Rajasthan                   1841                   1294
# 7   Uttar Pradesh                   3927                   2782
# 8     Uttarakhand                   2501                   1962
#
#    AA_Sample_Units_Urban  AA_Households_Total  AA_Households_Rural  \
# 0                    372               388853               319766
# 1                    375               612684               568030
# 2                    329               287085               226554
# 3                    595               392734               318142
# 4                    897               519811               357179
# 5                    566               477065               392913
# 6                    547               362671               300306
# 7                   1145               883613               710313
# 8                    539               392643               308474
#
#    AA_Households_Urban  AA_Population_Total  AA_Population_Rural  \
# 0                69087              1809610              1518639
# 1                44654              3227867              2993906
# 2                60531              1264309               994416
# 3                74592              2019298              1644036
# 4               162632              2389787              1629355
# 5                84152              1992799              1637152
# 6                62365              1828116              1521017
# 7               173300              4808503              3883293
# 8                84169              1726477              1365247
#
#    AA_Population_Urban  ...  \
# 0               290971  ...
# 1               233961  ...
# 2               269893  ...
# 3               375262  ...
# 4               760432  ...
# 5               355647  ...
# 6               307099  ...
# 7               925210  ...
# 8               361230  ...
#
#    ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Lower_Limit  \
# 0                                                 76
# 1                                                 71
# 2                                                 63
# 3                                                 56
# 4                                                 91
# 5                                                 78
# 6                                                 79
# 7                                                 96
# 8                                                 50
#
#    ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Upper_Limit  \
# 0                                                 79
# 1                                                 73
# 2                                                 67
# 3                                                 58
# 4                                                 94
# 5                                                 81
# 6                                                 82
# 7                                                 98
# 8                                                 53
#
#    ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Lower_Limit  \
# 0                                                 33
# 1                                                 48
# 2                                                 37
# 3                                                 27
# 4                                                 55
# 5                                                 45
# 6                                                 48
# 7                                                 61
# 8                                                 34
#
#    ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Upper_Limit  \
# 0                                                 40
# 1                                                 55
# 2                                                 43
# 3                                                 31
# 4                                                 59
# 5                                                 51
# 6                                                 55
# 7                                                 65
# 8                                                 40
#
#    ZZ_Sex_Ratio_At_Birth_Total_Lower_Limit  \
# 0                                      936
# 1                                      918
# 2                                      943
# 3                                      920
# 4                                      897
# 5                                      897
# 6                                      877
# 7                                      915
# 8                                      861
#
#    ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit  \
# 0                                      958
# 1                                      932
# 2                                      969
# 3                                      940
# 4                                      914
# 5                                      919
# 6                                      897
# 7                                      928
# 8                                      884
#
#    ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit  \
# 0                                      930
# 1                                      918
# 2                                      944
# 3                                      932
# 4                                      906
# 5                                      895
# 6                                      875
# 7                                      922
# 8                                      868
#
#    ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit  \
# 0                                      954
# 1                                      933
# 2                                      973
# 3                                      954
# 4                                      926
# 5                                      918
# 6                                      896
# 7                                      935
# 8                                      894
#
#    ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit  \
# 0                                      945
# 1                                      893
# 2                                      916
# 3                                      860
# 4                                      860
# 5                                      889
# 6                                      869
# 7                                      874
# 8                                      823
#
#    ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit
# 0                                     1009
# 1                                      953
# 2                                      975
# 3                                      909
# 4                                      893
# 5                                      943
# 6                                      920
# 7                                      904
# 8                                      877
#
# [9 rows x 643 columns]

# %%
key_indicator_districtwise = pd.read_csv("Key_indicator_districtwise.csv")
df2 = pd.DataFrame(key_indicator_districtwise)
df2.head(10)
# Out:
#   State_Name State_District_Name  AA_Sample_Units_Total  \
# 0      Assam             Barpeta                     53
# 1      Assam          Bongaigaon                     89
# 2      Assam              Cachar                    105
# 3      Assam             Darrang                     26
# 4      Assam             Dhemaji                    121
# 5      Assam              Dhubri                     42
# 6      Assam           Dibrugarh                     91
# 7      Assam            Goalpara                     64
# 8      Assam            Golaghat                     70
# 9      Assam          Hailakandi                     10
#
#    AA_Sample_Units_Rural  AA_Sample_Units_Urban  AA_Households_Total  \
# 0                     47                      6                13711
# 1                     73                     16                17384
# 2                     84                     21                27488
# 3                     24                      2                 5951
# 4                    108                     13                14481
# 5                     35                      7                11001
# 6                     66                     25                21378
# 7                     56                      8                15891
# 8                     61                      9                16021
# 9                      8                      2                 2802
#
#    AA_Households_Rural  AA_Households_Urban  AA_Population_Total  \
# 0                12765                  946                64606
# 1                14904                 2480                84012
# 2                24207                 3281               127158
# 3                 5769                  182                29048
# 4                12619                 1862                75451
# 5                 9954                 1047                50992
# 6                16514                 4864                97268
# 7                14630                 1261                75890
# 8                14183                 1838                72165
# 9                 2381                  421                13892
#
#    AA_Population_Rural  ...  \
# 0                60293  ...
# 1                73899  ...
# 2               112171  ...
# 3                28256  ...
# 4                66537  ...
# 5                46337  ...
# 6                76433  ...
# 7                70273  ...
# 8                64579  ...
# 9                11986  ...
#
#    ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Lower_Limit  \
# 0                                                 54
# 1                                                 58
# 2                                                 68
# 3                                                 79
# 4                                                 40
# 5                                                 79
# 6                                                 62
# 7                                                 66
# 8                                                 67
# 9                                                 75
#
#    ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Upper_Limit  \
# 0                                                 70
# 1                                                 73
# 2                                                 80
# 3                                                107
# 4                                                 53
# 5                                                100
# 6                                                 77
# 7                                                 81
# 8                                                 83
# 9                                                109
#
#    ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Lower_Limit  \
# 0                                                NaN
# 1                                                NaN
# 2                                               31.0
# 3                                                NaN
# 4                                               11.0
# 5                                                NaN
# 6                                               37.0
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Upper_Limit  \
# 0                                                NaN
# 1                                                NaN
# 2                                               57.0
# 3                                                NaN
# 4                                               38.0
# 5                                                NaN
# 6                                               64.0
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    ZZ_Sex_Ratio_At_Birth_Total_Lower_Limit  \
# 0                                      871
# 1                                      897
# 2                                      891
# 3                                      913
# 4                                      935
# 5                                      868
# 6                                      875
# 7                                      871
# 8                                      893
# 9                                      735
#
#    ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit  \
# 0                                      985
# 1                                     1005
# 2                                      966
# 3                                     1102
# 4                                     1045
# 5                                      998
# 6                                      972
# 7                                      976
# 8                                     1004
# 9                                      918
#
#    ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit  \
# 0                                      851
# 1                                      911
# 2                                      871
# 3                                      908
# 4                                      938
# 5                                      864
# 6                                      871
# 7                                      862
# 8                                      902
# 9                                      743
#
#    ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit  \
# 0                                      965
# 1                                     1026
# 2                                      949
# 3                                     1097
# 4                                     1054
# 5                                      998
# 6                                      977
# 7                                      969
# 8                                     1020
# 9                                      938
#
#    ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit  \
# 0                                    908.0
# 1                                    621.0
# 2                                    905.0
# 3                                      NaN
# 4                                    772.0
# 5                                    716.0
# 6                                    813.0
# 7                                    834.0
# 8                                    713.0
# 9                                    466.0
#
#    ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit
# 0                                   1611.0
# 1                                    956.0
# 2                                   1168.0
# 3                                      NaN
# 4                                   1083.0
# 5                                   1260.0
# 6                                   1046.0
# 7                                   1319.0
# 8                                   1032.0
# 9                                   1018.0
#
# [10 rows x 644 columns]

# %%
# Per State
df.describe()
# Out:
#        AA_Sample_Units_Total  AA_Sample_Units_Rural  AA_Sample_Units_Urban  \
# count               9.000000               9.000000               9.000000
# mean             2299.222222            1703.111111             596.111111
# std               738.802372             525.746004             266.659635
# min              1255.000000             926.000000             329.000000
# 25%              1841.000000            1412.000000             375.000000
# 50%              2356.000000            1660.000000             547.000000
# 75%              2501.000000            1962.000000             595.000000
# max              3927.000000            2782.000000            1145.000000
#
#        AA_Households_Total  AA_Households_Rural  AA_Households_Urban  \
# count             9.000000             9.000000             9.000000
# mean         479684.333333        389075.222222         90609.111111
# std          179108.137044        152837.981905         45610.159061
# min          287085.000000        226554.000000         44654.000000
# 25%          388853.000000        308474.000000         62365.000000
# 50%          392734.000000        319766.000000         74592.000000
# 75%          519811.000000        392913.000000         84169.000000
# max          883613.000000        710313.000000        173300.000000
#
#        AA_Population_Total  AA_Population_Rural  AA_Population_Urban  \
# count         9.000000e+00         9.000000e+00             9.000000
# mean          2.340752e+06         1.909673e+06        431078.333333
# std           1.071480e+06         9.173469e+05        241392.050217
# min           1.264309e+06         9.944160e+05        233961.000000
# 25%           1.809610e+06         1.518639e+06        290971.000000
# 50%           1.992799e+06         1.629355e+06        355647.000000
# 75%           2.389787e+06         1.644036e+06        375262.000000
# max           4.808503e+06         3.883293e+06        925210.000000
#
#        AA_Ever_Married_Women_Aged_15_49_Years_Total  ...  \
# count                                      9.000000  ...
# mean                                  442178.525556  ...
# std                                   175654.782983  ...
# min                                   251943.000000  ...
# 25%                                   349930.000000  ...
# 50%                                   385476.000000  ...
# 75%                                   471826.410000  ...
# max                                   835022.320000  ...
#
#        ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Lower_Limit  \
# count                                           9.000000
# mean                                           73.333333
# std                                            15.182226
# min                                            50.000000
# 25%                                            63.000000
# 50%                                            76.000000
# 75%                                            79.000000
# max                                            96.000000
#
#        ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Upper_Limit  \
# count                                           9.000000
# mean                                           76.111111
# std                                            15.086786
# min                                            53.000000
# 25%                                            67.000000
# 50%                                            79.000000
# 75%                                            82.000000
# max                                            98.000000
#
#        ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Lower_Limit  \
# count                                           9.000000
# mean                                           43.111111
# std                                            11.151731
# min                                            27.000000
# 25%                                            34.000000
# 50%                                            45.000000
# 75%                                            48.000000
# max                                            61.000000
#
#        ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Upper_Limit  \
# count                                           9.000000
# mean                                           48.777778
# std                                            10.917621
# min                                            31.000000
# 25%                                            40.000000
# 50%                                            51.000000
# 75%                                            55.000000
# max                                            65.000000
#
#        ZZ_Sex_Ratio_At_Birth_Total_Lower_Limit  \
# count                                 9.000000
# mean                                907.111111
# std                                  26.708821
# min                                 861.000000
# 25%                                 897.000000
# 50%                                 915.000000
# 75%                                 920.000000
# max                                 943.000000
#
#        ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit  \
# count                                 9.000000
# mean                                926.777778
# std                                  27.160531
# min                                 884.000000
# 25%                                 914.000000
# 50%                                 928.000000
# 75%                                 940.000000
# max                                 969.000000
#
#        ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit  \
# count                                 9.000000
# mean                                910.000000
# std                                  26.167728
# min                                 868.000000
# 25%                                 895.000000
# 50%                                 918.000000
# 75%                                 930.000000
# max                                 944.000000
#
#        ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit  \
# count                                 9.000000
# mean                                931.444444
# std                                  26.524098
# min                                 894.000000
# 25%                                 918.000000
# 50%                                 933.000000
# 75%                                 954.000000
# max                                 973.000000
#
#        ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit  \
# count                                 9.000000
# mean                                881.000000
# std                                  35.298725
# min                                 823.000000
# 25%                                 860.000000
# 50%                                 874.000000
# 75%                                 893.000000
# max                                 945.000000
#
#        ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit
# count                                 9.000000
# mean                                931.444444
# std                                  42.338254
# min                                 877.000000
# 25%                                 904.000000
# 50%                                 920.000000
# 75%                                 953.000000
# max                                1009.000000
#
# [8 rows x 642 columns]

# %%
# Per District
df2.describe()
# Out:
#        AA_Sample_Units_Total  AA_Sample_Units_Rural  AA_Sample_Units_Urban  \
# count             284.000000             284.000000             284.000000
# mean               72.862676              53.971831              18.890845
# std                49.310713              37.870795              24.083454
# min                10.000000               8.000000               2.000000
# 25%                46.000000              34.000000               7.000000
# 50%                60.000000              45.000000              12.000000
# 75%                82.000000              61.000000              20.000000
# max               386.000000             337.000000             234.000000
#
#        AA_Households_Total  AA_Households_Rural  AA_Households_Urban  \
# count           284.000000           284.000000           284.000000
# mean          15201.264085         12329.848592          2871.415493
# std            8360.819705          6621.757700          3900.137566
# min            2802.000000          2381.000000           153.000000
# 25%            9971.500000          7997.750000           971.000000
# 50%           13011.500000         10758.500000          1580.500000
# 75%           17749.000000         15250.000000          3044.250000
# max           66535.000000         47183.000000         35763.000000
#
#        AA_Population_Total  AA_Population_Rural  AA_Population_Urban  \
# count           284.000000           284.000000           284.000000
# mean          74178.753521         60517.820423         13660.933099
# std           38613.108658         31475.272720         17693.167257
# min           13892.000000         11722.000000           759.000000
# 25%           49222.500000         40206.500000          4613.000000
# 50%           65206.500000         53656.000000          7785.500000
# 75%           88998.500000         73290.000000         14757.500000
# max          303009.000000        238744.000000        155980.000000
#
#        AA_Ever_Married_Women_Aged_15_49_Years_Total  ...  \
# count                                    284.000000  ...
# mean                                   14012.871268  ...
# std                                     7395.232081  ...
# min                                     2501.000000  ...
# 25%                                     9229.250000  ...
# 50%                                    12368.500000  ...
# 75%                                    16442.750000  ...
# max                                    56581.000000  ...
#
#        ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Lower_Limit  \
# count                                         284.000000
# mean                                           71.366197
# std                                            19.116152
# min                                            21.000000
# 25%                                            59.750000
# 50%                                            70.000000
# 75%                                            83.000000
# max                                           130.000000
#
#        ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Upper_Limit  \
# count                                         284.000000
# mean                                           89.144366
# std                                            22.151828
# min                                            29.000000
# 25%                                            75.000000
# 50%                                            89.000000
# 75%                                           103.000000
# max                                           162.000000
#
#        ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Lower_Limit  \
# count                                         206.000000
# mean                                           35.558252
# std                                            16.359796
# min                                             0.000000
# 25%                                            25.000000
# 50%                                            34.000000
# 75%                                            44.000000
# max                                            84.000000
#
#        ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Upper_Limit  \
# count                                         206.000000
# mean                                           72.407767
# std                                            23.382268
# min                                            18.000000
# 25%                                            56.000000
# 50%                                            70.000000
# 75%                                            86.000000
# max                                           143.000000
#
#        ZZ_Sex_Ratio_At_Birth_Total_Lower_Limit  \
# count                               284.000000
# mean                                863.693662
# std                                  46.330749
# min                                 724.000000
# 25%                                 835.750000
# 50%                                 863.500000
# 75%                                 892.250000
# max                                1017.000000
#
#        ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit  \
# count                               284.000000
# mean                                973.954225
# std                                  51.091493
# min                                 813.000000
# 25%                                 939.000000
# 50%                                 973.000000
# 75%                                1004.000000
# max                                1148.000000
#
#        ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit  \
# count                               284.000000
# mean                                860.721831
# std                                  50.931015
# min                                 675.000000
# 25%                                 829.750000
# 50%                                 863.000000
# 75%                                 891.000000
# max                                1032.000000
#
#        ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit  \
# count                               284.000000
# mean                                981.823944
# std                                  53.467179
# min                                 833.000000
# 25%                                 949.000000
# 50%                                 978.000000
# 75%                                1009.500000
# max                                1186.000000
#
#        ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit  \
# count                               275.000000
# mean                                749.727273
# std                                  96.156437
# min                                 391.000000
# 25%                                 690.000000
# 50%                                 751.000000
# 75%                                 819.000000
# max                                1000.000000
#
#        ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit
# count                               275.000000
# mean                               1093.789091
# std                                 141.964062
# min                                 798.000000
# 25%                                 992.500000
# 50%                                1064.000000
# 75%                                1172.000000
# max                                1611.000000
#
# [8 rows x 642 columns]

# %%
# Per State
df.columns
# Out:
# Index(['State_Name', 'AA_Sample_Units_Total', 'AA_Sample_Units_Rural',
#        'AA_Sample_Units_Urban', 'AA_Households_Total', 'AA_Households_Rural',
#        'AA_Households_Urban', 'AA_Population_Total', 'AA_Population_Rural',
#        'AA_Population_Urban',
#        ...
#        'ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Lower_Limit',
#        'ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Upper_Limit',
#        'ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Lower_Limit',
#        'ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Upper_Limit',
#        'ZZ_Sex_Ratio_At_Birth_Total_Lower_Limit',
#        'ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit',
#        'ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit',
#        'ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit',
#        'ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit',
#        'ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit'],
#       dtype='object', length=643)

# %%
# Per District
df2.columns
# Out:
# Index(['State_Name', 'State_District_Name', 'AA_Sample_Units_Total',
#        'AA_Sample_Units_Rural', 'AA_Sample_Units_Urban', 'AA_Households_Total',
#        'AA_Households_Rural', 'AA_Households_Urban', 'AA_Population_Total',
#        'AA_Population_Rural',
#        ...
#        'ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Lower_Limit',
#        'ZZ_Under_Five_Mortality_Rate_U5MR_Rural_Upper_Limit',
#        'ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Lower_Limit',
#        'ZZ_Under_Five_Mortality_Rate_U5MR_Urban_Upper_Limit',
#        'ZZ_Sex_Ratio_At_Birth_Total_Lower_Limit',
#        'ZZ_Sex_Ratio_At_Birth_Total_Upper_Limit',
#        'ZZ_Sex_Ratio_At_Birth_Rural_Lower_Limit',
#        'ZZ_Sex_Ratio_At_Birth_Rural_Upper_Limit',
#        'ZZ_Sex_Ratio_At_Birth_Urban_Lower_Limit',
#        'ZZ_Sex_Ratio_At_Birth_Urban_Upper_Limit'],
#       dtype='object', length=644)

# %%
# Counts of each unique name per state
df['State_Name'].value_counts()
# Out:
# State_Name
# Assam             1
# Bihar             1
# Chhattisgarh      1
# Jharkhand         1
# Madhya Pradesh    1
# Odisha            1
# Rajasthan         1
# Uttar Pradesh     1
# Uttarakhand       1
# Name: count, dtype: int64

# %%
df['State_Name'].unique()
# Out:
# array(['Assam', 'Bihar', 'Chhattisgarh', 'Jharkhand', 'Madhya Pradesh',
#        'Odisha', 'Rajasthan', 'Uttar Pradesh', 'Uttarakhand'],
#       dtype=object)

# %%
# Counts of each unique name per district
df2['State_District_Name'].value_counts()
# Out:
# State_District_Name
# Barpeta              1
# Bongaigaon           1
# Cachar               1
# Darrang              1
# Dhemaji              1
#                     ..
# Pithoragarh          1
# Rudraprayag          1
# Tehri Garhwal        1
# Udham Singh Nagar    1
# Uttarkashi           1
# Name: count, Length: 284, dtype: int64

# %%
df2['State_District_Name'].unique()
# Out:
# array(['Barpeta', 'Bongaigaon', 'Cachar', 'Darrang', 'Dhemaji', 'Dhubri',
#        'Dibrugarh', 'Goalpara', 'Golaghat', 'Hailakandi', 'Jorhat',
#        'Kamrup', 'Karbi Anglong', 'Karimganj', 'Kokrajhar', 'Lakhimpur',
#        'Marigaon', 'Nagaon', 'Nalbari', 'North Cachar Hills', 'Sibsagar',
#        'Sonitpur', 'Tinsukia', 'Araria', 'Aurangabad', 'Banka',
#        'Begusarai', 'Bhagalpur', 'Bhojpur', 'Buxar', 'Darbhanga', 'Gaya',
#        'Gopalganj', 'Jamui', 'Jehanabad', 'Kaimur (Bhabua)', 'Katihar',
#        'Khagaria', 'Kishanganj', 'Lakhisarai', 'Madhepura', 'Madhubani',
#        'Munger', 'Muzaffarpur', 'Nalanda', 'Nawada', 'Pashchim Champaran',
#        'Patna', 'Purba Champaran', 'Purnia', 'Rohtas', 'Saharsa',
#        'Samastipur', 'Saran', 'Sheikhpura', 'Sheohar', 'Sitamarhi',
#        'Siwan', 'Supaul', 'Vaishali', 'Bastar', 'Bilaspur', 'Dantewada',
#        'Dhamtari', 'Durg', 'Janjgir-Champa', 'Jashpur', 'Kanker',
#        'Kawardha', 'Korba', 'Koriya', 'Mahasamund', 'Raigarh', 'Raipur',
#        'Rajnandgaon', 'Surguja', 'Bokaro', 'Chatra', 'Deoghar', 'Dhanbad',
#        'Dumka', 'Garhwa', 'Giridih', 'Godda', 'Gumla', 'Hazaribagh',
#        'Kodarma', 'Lohardaga', 'Pakaur', 'Palamu', 'Pashchimi Singhbhum',
#        'Purbi Singhbhum', 'Ranchi', 'Sahibganj', 'Balaghat', 'Barwani',
#        'Betul', 'Bhind', 'Bhopal', 'Chhatarpur', 'Chhindwara', 'Damoh',
#        'Datia', 'Dewas', 'Dhar', 'Dindori', 'East Nimar', 'Guna',
#        'Gwalior', 'Harda', 'Hoshangabad', 'Indore', 'Jabalpur', 'Jhabua',
#        'Katni', 'Mandla', 'Mandsaur', 'Morena', 'Narsimhapur', 'Neemuch',
#        'Panna', 'Raisen', 'Rajgarh', 'Ratlam', 'Rewa', 'Sagar', 'Satna',
#        'Sehore', 'Seoni', 'Shahdol', 'Shajapur', 'Sheopur', 'Shivpuri',
#        'Sidhi', 'Tikamgarh', 'Ujjain', 'Umaria', 'Vidisha', 'West Nimar',
#        'Anugul', 'Balangir', 'Baleshwar', 'Bargarh', 'Baudh', 'Bhadrak',
#        'Cuttack', 'Debagarh', 'Dhenkanal', 'Gajapati', 'Ganjam',
#        'Jagatsinghapur', 'Jajapur', 'Jharsuguda', 'Kalahandi',
#        'Kandhamal', 'Kendrapara', 'Kendujhar', 'Khordha', 'Koraput',
#        'Malkangiri', 'Mayurbhanj', 'Nabarangapur', 'Nuapada', 'Nayagarh',
#        'Puri', 'Rayagada', 'Sambalpur', 'Sonapur', 'Sundargarh', 'Ajmer',
#        'Alwar', 'Banswara', 'Baran', 'Barmer', 'Bharatpur', 'Bhilwara',
#        'Bikaner', 'Bundi', 'Chittaurgarh', 'Churu', 'Dausa', 'Dhaulpur',
#        'Dungarpur', 'Ganganagar', 'Hanumangarh', 'Jaipur', 'Jaisalmer',
#        'Jalor', 'Jhalawar', 'Jhunjhunun', 'Jodhpur', 'Karauli', 'Kota',
#        'Nagaur', 'Pali', 'Rajsamand', 'Sawai Madhopur', 'Sikar', 'Sirohi',
#        'Tonk', 'Udaipur', 'Agra', 'Aligarh', 'Allahabad',
#        'Ambedkar Nagar', 'Auraiya', 'Azamgarh', 'Baghpat', 'Bahraich',
#        'Ballia', 'Balrampur', 'Banda', 'Barabanki', 'Bareilly', 'Basti',
#        'Bijnor', 'Budaun', 'Bulandshahar', 'Chandauli', 'Chitrakoot',
#        'Deoria', 'Etah', 'Etawah', 'Faizabad', 'Farrukhabad', 'Fatehpur',
#        'Firozabad', 'Gautam Buddha Nagar', 'Ghaziabad', 'Ghazipur',
#        'Gonda', 'Gorakhpur', 'Hamirpur', 'Hardoi', 'Hathras', 'Jalaun',
#        'Jaunpur', 'Jhansi', 'Jyotiba Phule Nagar', 'Kannauj',
#        'Kanpur Dehat', 'Kanpur Nagar', 'Kaushambi', 'Kheri', 'Kushinagar',
#        'Lalitpur', 'Lucknow', 'Maharajganj', 'Mahoba', 'Mainpuri',
#        'Mathura', 'Mau', 'Meerut', 'Mirzapur', 'Moradabad',
#        'Muzaffarnagar', 'Pilibhit', 'Pratapgarh', 'Rae Bareli', 'Rampur',
#        'Saharanpur', 'Sant Kabir Nagar', 'Sant Ravidas Nagar (Bhadohi)',
#        'Shahjahanpur', 'Shrawasti', 'Siddharthnagar', 'Sitapur',
#        'Sonbhadra', 'Sultanpur', 'Unnao', 'Varanasi', 'Almora',
#        'Bageshwar', 'Chamoli', 'Champawat', 'Dehradun', 'Haridwar',
#        'Nainital', 'Pauri Garhwal', 'Pithoragarh', 'Rudraprayag',
#        'Tehri Garhwal', 'Udham Singh Nagar', 'Uttarkashi'], dtype=object)

# %%
df['State_Name'].nunique()
# Out:
# 9

# %%
df2['State_District_Name'].nunique()
# Out:
# 284

# %% [markdown]
# ### Health Analytics Dataset: Source Directory - Per State and District

# %% [markdown]
# The Health Analytics dataset is distinctly aggregated by state and district. States are similar to US states in America, whereas districts are similar
# to US counties respectively.
#
# There are **28** states in India with an estimate of **~780 - 806** districts according to Google, respectively. The Health Analytics dataset, from preliminary EDA indicate only **9** of the **28** states are represented in this dataset, and only **284** of the **780 - 806** districts are represented here from our findings.
#
# EDA by state, this represents roughly only **~32%** of India's total population without aggregating discrepancies and further data validation.

# %%
# See Key_Indicator_State_and_District_wise_data directory for more information
os.chdir('../data/Key_Indicator_State_and_District_wise_data')
print('Source Directory of Health Analytics Dataset:')
# !ls
# Out:
# Source Directory of Health Analytics Dataset:
# AA_Sample_Particulars_District.csv
# AA_Sample_Particulars_State.csv
# BB_Household_Characteristics_District.csv
# BB_Household_Characteristics_State.csv
# CC_Sex_Ratio_District.csv
# CC_Sex_Ratio_State.csv
# DD_Effective_Literacy_Rate_District.csv
# DD_Effective_Literacy_Rate_State.csv
# EE_Marriage_District.csv
# EE_Marriage_State.csv
# FF_Schooling_Status_District.csv
# FF_Schooling_Status_State.csv
# GG_Work_Status_District.csv
# GG_Work_Status_State.csv
# HH_Disability_District.csv
# HH_Disability_State.csv
# II_Injury_District.csv
# II_Injury_State.csv
# JJ_Acute_Illness_District.csv
# JJ_Acute_Illness_State.csv
# KK_Chronic_Illness_District.csv
# KK_Chronic_Illness_State.csv
# Key_Indicator_State_and_District_wise_data
# LL_Fertility_District.csv
# LL_Fertility_State.csv
# MM_Abortion_District.csv
# MM_Abortion_State.csv
# NN_Family_Planning_Practices_Cmw_Aged_15_49_Years_District.csv
# NN_Family_Planning_Practices_Cmw_Aged_15_49_Years_State.csv
# OO_Unmet_Need_For_Family_Planning_District.csv
# OO_Unmet_Need_For_Family_Planning_State.csv
# PP_Ante_Natal_Care_District.csv
# PP_Ante_Natal_Care_State.csv
# QQ_Delivery_Care_District.csv
# QQ_Delivery_Care_State.csv
# RR_Post_Natal_Care_District.csv
# RR_Post_Natal_Care_State.csv
# SS_Janani_Suraksha_Yojana_JSY_District.csv
# SS_Janani_Suraksha_Yojana_JSY_State.csv
# TT_Immunization_Vitamin_A_Iron_Supplement_And_Birth_Weight_District.csv
# TT_Immunization_Vitamin_A_Iron_Supplement_And_Birth_Weight_State.csv
# UU_Childhood_Diseases_District.csv
# UU_Childhood_Diseases_State.csv
# VV_Breastfeeding_And_Supplementation_District.csv
# VV_Breastfeeding_And_Supplementation_State.csv
# WW_Birth_Registration_District.csv
# WW_Birth_Registration_State.csv
# XX_Awareness_On_HIV_AIDS_RTI_STI_HAF_ORS_ORT_ZINC_And_ARI_Pneumonia_District.csv
# XX_Awareness_On_HIV_AIDS_RTI_STI_HAF_ORS_ORT_ZINC_And_ARI_Pneumonia_State.csv
# YY_Mortality_District.csv
# YY_Mortality_State.csv
# ZZ_Confidence_Interval_95_Percent_For_Some_Important_Indicators_District.csv
# ZZ_Confidence_Interval_95_Percent_For_Some_Important_Indicators_State.csv

# %%
#%pip install matplotlib

# %%
import pandas as pd

# List of prefixes to search
prefixes = ["YY_Under", "YY_Neo", "YY_Post", "YY_Infant"]

# Function to filter column names by prefixes
def get_matching_columns(df, prefixes):
    return [col for col in df.columns if any(pref in col for pref in prefixes)]

# Extract matches
df_cols = get_matching_columns(df, prefixes)
df2_cols = get_matching_columns(df2, prefixes)

# Convert to DataFrames for stdout
df_cols_df = pd.DataFrame(df_cols, columns=["df Columns"])
df2_cols_df = pd.DataFrame(df2_cols, columns=["df2 Columns"])

print("Preliminary EDA for Infant Mortality Rates. Columns:")
print("Matching columns in df (per state):")
print(df_cols_df)

print("\nMatching columns in df2 (per district):")
print(df2_cols_df)
# Out:
# Preliminary EDA for Infant Mortality Rates. Columns:
# Matching columns in df:
#                                         df Columns
# 0        YY_Infant_Mortality_Rate_Imr_Total_Person
# 1          YY_Infant_Mortality_Rate_Imr_Total_Male
# 2        YY_Infant_Mortality_Rate_Imr_Total_Female
# 3        YY_Infant_Mortality_Rate_Imr_Rural_Person
# 4          YY_Infant_Mortality_Rate_Imr_Rural_Male
# 5        YY_Infant_Mortality_Rate_Imr_Rural_Female
# 6        YY_Infant_Mortality_Rate_Imr_Urban_Person
# 7          YY_Infant_Mortality_Rate_Imr_Urban_Male
# 8        YY_Infant_Mortality_Rate_Imr_Urban_Female
# 9                YY_Neo_Natal_Mortality_Rate_Total
# 10               YY_Neo_Natal_Mortality_Rate_Rural
# 11               YY_Neo_Natal_Mortality_Rate_Urban
# 12          YY_Post_Neo_Natal_Mortality_Rate_Total
# 13          YY_Post_Neo_Natal_Mortality_Rate_Rural
# 14          YY_Post_Neo_Natal_Mortality_Rate_Urban
# 15  YY_Under_Five_Mortality_Rate_U5MR_Total_Person
# 16    YY_Under_Five_Mortality_Rate_U5MR_Total_Male
# 17  YY_Under_Five_Mortality_Rate_U5MR_Total_Female
# 18  YY_Under_Five_Mortality_Rate_U5MR_Rural_Person
# 19    YY_Under_Five_Mortality_Rate_U5MR_Rural_Male
# 20  YY_Under_Five_Mortality_Rate_U5MR_Rural_Female
# 21  YY_Under_Five_Mortality_Rate_U5MR_Urban_Person
# 22    YY_Under_Five_Mortality_Rate_U5MR_Urban_Male
# 23  YY_Under_Five_Mortality_Rate_U5MR_Urban_Female
#
# Matching columns in df2:
#                                        df2 Columns
# 0        YY_Infant_Mortality_Rate_Imr_Total_Person
# 1          YY_Infant_Mortality_Rate_Imr_Total_Male
# 2        YY_Infant_Mortality_Rate_Imr_Total_Female
# 3        YY_Infant_Mortality_Rate_Imr_Rural_Person
# 4          YY_Infant_Mortality_Rate_Imr_Rural_Male
# 5        YY_Infant_Mortality_Rate_Imr_Rural_Female
# 6        YY_Infant_Mortality_Rate_Imr_Urban_Person
# 7          YY_Infant_Mortality_Rate_Imr_Urban_Male
# 8        YY_Infant_Mortality_Rate_Imr_Urban_Female
# 9                YY_Neo_Natal_Mortality_Rate_Total
# 10               YY_Neo_Natal_Mortality_Rate_Rural
# 11               YY_Neo_Natal_Mortality_Rate_Urban
# 12          YY_Post_Neo_Natal_Mortality_Rate_Total
# 13          YY_Post_Neo_Natal_Mortality_Rate_Rural
# 14          YY_Post_Neo_Natal_Mortality_Rate_Urban
# 15  YY_Under_Five_Mortality_Rate_U5MR_Total_Person
# 16    YY_Under_Five_Mortality_Rate_U5MR_Total_Male
# 17  YY_Under_Five_Mortality_Rate_U5MR_Total_Female
# 18  YY_Under_Five_Mortality_Rate_U5MR_Rural_Person
# 19    YY_Under_Five_Mortality_Rate_U5MR_Rural_Male
# 20  YY_Under_Five_Mortality_Rate_U5MR_Rural_Female
# 21  YY_Under_Five_Mortality_Rate_U5MR_Urban_Person
# 22    YY_Under_Five_Mortality_Rate_U5MR_Urban_Male
# 23  YY_Under_Five_Mortality_Rate_U5MR_Urban_Female

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# --- configs ---
PREFIXES = ["YY_Infant", "YY_Under", "YY_Neo", "YY_Post"]  # can add more feature columns here (by prefix)
GROUP_COL_CANDIDATES = ["State_Name", "State_District_Name"] # can add more feature columns here (by group/category. state, locations, etc)

# --- helpers ---
def find_group_col(df):
    for c in GROUP_COL_CANDIDATES:
        if c in df.columns:
            return c
    return None  

def cols_with_prefixes(df, prefixes):
    cols = []
    for p in prefixes:
        cols.extend([c for c in df.columns if c.startswith(p)])
    return list(dict.fromkeys(cols))  

def melt_prefixes(df, prefixes):
    yy_cols = cols_with_prefixes(df, prefixes)
    id_vars = [c for c in df.columns if c not in yy_cols]
    tidy = df.melt(id_vars=id_vars, value_vars=yy_cols,
                   var_name="yy_feature", value_name="value")
    tidy["value"] = pd.to_numeric(tidy["value"], errors="coerce")
    # add top-level prefix label for quick faceting/grouping
    tidy["prefix"] = tidy["yy_feature"].str.extract(r"^(YY_[A-Za-z]+)")
    return tidy

def plot_overall_means_by_prefix(tidy):
    agg = tidy.groupby("prefix", dropna=True)["value"].mean().reset_index()
    plt.figure(figsize=(7,4))
    plt.bar(agg["prefix"], agg["value"])
    plt.title("Overall Mean by Prefix Feature Column")
    plt.ylabel("Mean Value")
    plt.xticks(rotation=15, ha="right")
    plt.tight_layout()
    plt.show()

def plot_top_groups_for_prefix(tidy, prefix, group_col, top_n=10):
    if group_col is None:
        print(f"[info] No group column found; skipping group ranking for {prefix}.")
        return
    sub = tidy[(tidy["prefix"] == prefix)].copy()
    agg = sub.groupby(group_col, dropna=True)["value"].mean().sort_values(ascending=False).head(top_n)
    plt.figure(figsize=(8,5))
    plt.barh(agg.index[::-1], agg.values[::-1])
    plt.title(f"Top {top_n} {group_col}s by Mean {prefix}")
    plt.xlabel("Mean Value")
    plt.tight_layout()
    plt.show()

def plot_corr_of_selected(df, prefixes):
    sel_cols = cols_with_prefixes(df, prefixes)
    if not sel_cols:
        print("[warn] No columns found for the given prefixes.")
        return
    num = df[sel_cols].apply(pd.to_numeric, errors="coerce")
    corr = num.corr()
    plt.figure(figsize=(8,6))
    plt.imshow(corr, interpolation="nearest")
    plt.colorbar()
    plt.title("Correlation (selected YY_* columns)")
    plt.xticks(range(len(sel_cols)), sel_cols, rotation=90)
    plt.yticks(range(len(sel_cols)), sel_cols)
    plt.tight_layout()
    plt.show()

# --- Preliminary on Health Analytics Data ---
# Check dataframes (By State - preliminary EDA ond data)
group_col = find_group_col(df)
tidy = melt_prefixes(df, PREFIXES)

# 1) Check columns per prefix)
counts = (pd.Series(cols_with_prefixes(df, PREFIXES))
          .str.extract(r"^(YY_[A-Za-z]+)")[0]
          .value_counts())
print("Feature Columns For Capstone Project (May require further look at dataset):")
print("Feature Columns Found per Prefix Column:\n", counts.to_string(), "\n")

# 2) Overall average means by prefix
plot_overall_means_by_prefix(tidy)

# 3) Highest feature column numbers (e.g., States/Districts) for each prefix
for p in sorted(tidy["prefix"].dropna().unique()):
    plot_top_groups_for_prefix(tidy, p, group_col, top_n=10)

# 4) Correlation heatmap among all selected YY_* columns
#plot_corr_of_selected(df, PREFIXES)
# Out:
# Feature Columns For Capstone Project (May require further look at dataset):
# Feature Columns Found per Prefix Column:
#  0
# YY_Infant    9
# YY_Under     9
# YY_Neo       3
# YY_Post      3

# %%
# end of preliminary analysis/overview on capstone project data
