# %% [markdown]
# ## Null/Missing Values (By State)

# %% [markdown]
# wip

# %%
print("placemarker notebook. run a check on null/missing values")
# Out:
# placemarker notebook. run a check on null/missing values
